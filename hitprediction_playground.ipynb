# %%
from sklearn.model_selection import StratifiedGroupKFold
import json
import pandas as pd

# %%
edge_dataset = json.load(open("/raid/home/smelo/smokesquadrondataset/ss_hitpred/edge_dataset/edgedataset.json", "r"))
print(edge_dataset)
# Out:
# [{'source': 419, 'target': 418, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 442, 'target': 441, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 460, 'target': 459, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 485, 'target': 484, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 499, 'target': 498, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 507, 'target': 506, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 515, 'target': 514, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 517, 'target': 516, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 1660, 'target': 1659, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 1665, 'target': 1664, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 1667, 'target': 1666, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 1671, 'target': 1670, 'class': 1, 'origin': '2023-05-09-18-04-52.xml'}, {'source': 1675, 
# ...

# %%
edge_dataset_df = pd.DataFrame.from_dict(edge_dataset)

# %%
test_row = edge_dataset_df.loc[0]
print(test_row["origin"])
# Out:
# 2023-05-09-18-04-52.xml
